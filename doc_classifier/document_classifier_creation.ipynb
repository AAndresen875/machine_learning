# %%
import os
import numpy as np
import re
import nltk
import pandas as pd
from sklearn.datasets import load_files
from sklearn.model_selection import train_test_split
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/andre875/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Document Classifying ML model.
#
# This model is trained on being able to thew type of file it looking at based off of training data of similar file types. The trained model will be loaded into pickle to be used to classify new instances of those bill. Ideal for automated data model routing for a data ingestion pipeline. This model is trained off of the english language, and will reduce effectiveness
#
# Example:
# * doctor's bills vs electric bills
#
# ## Notes:
# * This will be an Naive Bayes (NB) Classifier
# * count vectorizer is a high level component which will create feature vectors for us. Seperated by a space for english (leveraging te nltk)
# * TF: will refer to term frequency
# * TF-IDF: term frequency times inverse document frequency
#
# ## Similar articles for reading:
# https://iq.opengenus.org/naive-bayes-on-tf-idf-vectorized-matrix/
# https://towardsdatascience.com/understanding-text-vectorizations-ii-how-tf-idf-gives-your-simple-models-the-power-to-rival-the-79b6c975d7eb
# https://medium.com/artificial-coder/count-vectorizers-vs-tfidf-vectorizers-natural-language-processing-b5371f51a40c

# %% [markdown]
# ### Importing files to be train the model

# %%
# assigning the path to the folder your files are in:
path_to_data = os.path.join(os.getcwd(),'all_files')
print(path_to_data)
#loading in the data with the data as the data and the folder name as the data label:
# see info on the function load_files() for more information
data_to_sort = load_files(path_to_data, encoding='cp1252')
print("amount of files", len(data_to_sort.data))
X, y = data_to_sort.data, data_to_sort.target

# %% [markdown]
# ## Splitting training and testing data

# %%
from sklearn.model_selection import train_test_split
#TODO confirm random_state you'd like to pass in
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(len(X_train))

# %% [markdown]
# ### Building the pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

# %%
# creating the pipeline components
text_clf2 = Pipeline(
    [
        ('vect', CountVectorizer(stop_words='english')), 
        ('tfidf', TfidfTransformer()), ('clf', MultinomialNB)
        ]
    )
text_clf2 = text_clf2.fit(X_train, y_train)
text_clf2

# %% [markdown]
# ### Predicting the target of the test data

# %%
predicted = test_clf2.predict(X_text)
predicted

# %% [markdown]
# ### Evaluation of the test data predictions:
# testing performance  0=0%, 1 =100%

# %%
performance_metric = np.mean(predicted == y_test)
performance_metric

# %% [markdown]
# # translating vector stats to human readable information

# %%
output_of_model = pd.Dataframe(predicted, columns=['predicted_type'])
output_of_model['file']= X_test
output_of_model.head()

# %% [markdown]
# ## Seeing which files were named what

# %% [markdown]
# output_of_model['predicted_type'].value_counts()

# %% [markdown]
# # Saving the model as a pickle file to be used elsewhere

# %%
with open('file_classifier', 'wb') as picklefile:
    pickle.dump(text_clf2, picklefile)
